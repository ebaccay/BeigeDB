# %% [markdown]
# # Text Cleaning the Beige Books

# %%
# Code Borrowed from UC Berkeley's Data 8 lab/homework modules for simplicity
# http://data8.org/
import numpy as np
from datascience import *

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)
from matplotlib import patches

# %%
beige_books = Table.read_table('beige_books.csv')
print("Pre-cleaning length: " + str(beige_books.num_rows))
beige_books
# Out:
# Pre-cleaning length: 25273
# ID   | Date      | District     | Sector Heading                     | Sector Text
# 1    | 5-20-1970 | Atlanta      | Summary of Economic Activity       | The mood of our directors varies from pessimism to optim ...
# 2    | 5-20-1970 | Boston       | Summary of Economic Activity       | Discussions Monday (May 18) and last Friday with First D ...
# 3    | 5-20-1970 | Chicago      | Summary of Economic Activity       | In published statements and private conversations a deep ...
# 4    | 5-20-1970 | Cleveland    | Summary of Economic Activity       | Economic activity in the District has been disrupted dur ...
# 5    | 5-20-1970 | Dallas       | Summary of Economic Activity       | Continued inflation is the major concern of Eleventh Dis ...
# 6    | 5-20-1970 | Kansas City  | Summary of Economic Activity       | Consensus Based on Discussions with Members of the Board ...
# 7    | 5-20-1970 | Minneapolis  | Summary of Economic Activity       | Although indications of softening in the Ninth Federal R ...
# 8    | 5-20-1970 | New York     | Summary of Economic Activity       | In the Second Federal Reserve District, the Boards of Di ...
# 9    | 5-20-1970 | Philadelphia | Summary of Economic Activity       | The business slowdown in the regional economy is now in  ...
# 10   | 5-20-1970 | Richmond     | Production, Sales, and Inventories | District survey respondents, except for those in certain ...
# ... (25263 rows omitted)

# %%
beige_books = beige_books.where('ID', lambda s: s.isdigit())
beige_books.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Date</th> <th>District</th> <th>Sector Heading</th> <th>Sector Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>5-20-1970</td> <td>Atlanta </td> <td>Summary of Economic Activity</td> <td>The mood of our directors varies from pessimism to optim ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2   </td> <td>5-20-1970</td> <td>Boston  </td> <td>Summary of Economic Activity</td> <td>Discussions Monday (May 18) and last Friday with First D ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>3   </td> <td>5-20-1970</td> <td>Chicago </td> <td>Summary of Economic Activity</td> <td>In published statements and private conversations a deep ...</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (25266 rows omitted)</p>

# %% [markdown]
# # Cleaning Empty Sector Texts

# %%
empty_rows = beige_books.where("Sector Text", "nan")
empty_rows.show(3)
empty_row_ids = empty_rows.apply(lambda i: int(i), "ID")
empty_row_ids
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Date</th> <th>District</th> <th>Sector Heading</th> <th>Sector Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>21  </td> <td>5-20-1970</td> <td>San Francisco</td> <td>Summary for Selected Economic Aspects          </td> <td>nan        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>30  </td> <td>5-20-1970</td> <td>San Francisco</td> <td>Inventories                                    </td> <td>nan        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>31  </td> <td>5-20-1970</td> <td>San Francisco</td> <td>Both higher and lower inventories are reported.</td> <td>nan        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (136 rows omitted)</p>
# array([   21,    30,    31,    93,   122,   136,   217,   259,   585,
#          629,   711,   789,   842,  1007,  1287,  1366,  1989,  2456,
#         2714,  3172,  5795,  5796,  5797,  5798,  5799,  5800,  5801,
#         5802,  5803,  5804,  5805,  5806,  5807,  5808,  5809,  5810,
#         5811,  5812,  5813,  5814,  6337,  6338,  6339,  6340,  6341,
#         6342,  6343,  6344,  6345,  6346,  6347,  6348,  6349,  6350,
#         6351,  6352,  6353,  6354,  6355,  6356,  6420,  6421,  6422,
#         6423,  6424,  6425,  6426,  6427,  6428,  6429,  6430,  6431,
#         6432,  6433,  6434,  6435,  6436,  6437,  6438,  6439,  6440,
#         6441,  6442,  6443,  6444,  6798,  6826,  6827,  6828,  6829,
#         6830,  6831,  6832,  6833,  6834,  6835,  6836,  6837,  6838,
#         6839,  6840,  8368,  8731,  9527, 10411, 13392, 13941, 14403,
#        16885, 18276, 18279, 18301, 19409, 20704, 21018, 21475, 21560,
#        21563, 21588, 21602, 21673, 21721, 21810, 21836, 21901, 21990,
#        22080, 22170, 22437, 22526, 22529, 22707, 22895, 22956, 23532,
#        23576, 23713, 24843, 25175])

# %%
ids_of_interest = []
empty_row_id = []
for i in empty_row_ids:
    empty_row_id.append(i)
    if i not in ids_of_interest:
        ids_of_interest.append(i - 1)
        ids_of_interest.append(i)
        ids_of_interest.append(i + 1)
    
ids_not_of_interest = [20, 21, 22, 29, 30, 31, 92, 93, 94, 121, 122, 123, 135, 136, 137]
ids_not_of_interest.extend([216, 217, 218, 260, 586, 258, 259, 584, 585, 628, 629, 630])
ids_not_of_interest.extend([])

for ids in ids_not_of_interest:
    ids_of_interest.remove(ids)
    
ids_of_interest = np.array(sorted(list(set(ids_of_interest))))

# %%
rows_of_interests = beige_books.where("ID", lambda i: int(i) in ids_of_interest)
rows_of_interests.show(300)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Date</th> <th>District</th> <th>Sector Heading</th> <th>Sector Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>710  </td> <td>1-15-1975 </td> <td>Atlanta      </td> <td>Summary of Economic Activity                     </td> <td>While the Sixth District economy remains below par, seve ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>711  </td> <td>1-15-1975 </td> <td>Atlanta      </td> <td>capital-spending plans.                          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>712  </td> <td>1-15-1975 </td> <td>Boston       </td> <td>Summary of Economic Activity                     </td> <td>In New England the mood is bad, but directors note that  ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>788  </td> <td>7-9-1975  </td> <td>Kansas City  </td> <td>Summary of Economic Activity                     </td> <td>A survey of a number of Tenth District purchasing manage ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>789  </td> <td>7-9-1975  </td> <td>Kansas City  </td> <td>1-year CD's.                                     </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>790  </td> <td>7-9-1975  </td> <td>Minneapolis  </td> <td>Summary of Economic Activity                     </td> <td>At midyear, the economic decline in the Ninth District a ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>841  </td> <td>11-12-1975</td> <td>Philadelphia </td> <td>Summary of Economic Activity                     </td> <td>Economic activity in the Third District is growing, but  ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>842  </td> <td>11-12-1975</td> <td>Philadelphia </td> <td>tax-exempt income.                               </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>843  </td> <td>11-12-1975</td> <td>Richmond     </td> <td>Summary of Economic Activity                     </td> <td>The November survey of Fifth District business condition ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1006 </td> <td>1-13-1977 </td> <td>Chicago      </td> <td>Summary of Economic Activity                     </td> <td>The economic outlook in the Seventh District continues t ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1007 </td> <td>1-13-1977 </td> <td>Chicago      </td> <td>1973-74.                                         </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1008 </td> <td>1-13-1977 </td> <td>Cleveland    </td> <td>Summary of Economic Activity                     </td> <td>The pace of economic activity will apparently quicken th ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1286 </td> <td>9-13-1978 </td> <td>Boston       </td> <td>Summary of Economic Activity                     </td> <td>The level of economic activity in the First District rem ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1287 </td> <td>9-13-1978 </td> <td>Boston       </td> <td>policy-induced recession at this time.           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1288 </td> <td>9-13-1978 </td> <td>Chicago      </td> <td>Summary of Economic Activity                     </td> <td>The expansion in the Seventh District doubtless has slow ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1365 </td> <td>4-11-1979 </td> <td>Minneapolis  </td> <td>Widespread Strength and Optimism                 </td> <td>District manufacturers seem to be having a very good yea ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1366 </td> <td>4-11-1979 </td> <td>Minneapolis  </td> <td>A Slowdown and a Threat                          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1367 </td> <td>4-11-1979 </td> <td>Minneapolis  </td> <td>Not everything looks rosy, however.              </td> <td>For one thing, the district's construction industry is w ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1988 </td> <td>8-11-1981 </td> <td>Cleveland    </td> <td>Summary                                          </td> <td>Respondents in the Fourth District generally view the gr ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1989 </td> <td>8-11-1981 </td> <td>Cleveland    </td> <td><>                                               </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1990 </td> <td>8-11-1981 </td> <td>Cleveland    </td> <td>>Output and Prices                               </td> <td>Most respondents have scaled down their third and fourth ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2455 </td> <td>6-23-1982 </td> <td>Cleveland    </td> <td>Employment                                       </td> <td>Labor markets in the District remain weak, and unemploym ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2456 </td> <td>6-23-1982 </td> <td>Cleveland    </td> <td><>                                               </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2457 </td> <td>6-23-1982 </td> <td>Cleveland    </td> <td>>Manufacturing Activity                          </td> <td>A variety of manufacturers in the District report little ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2713 </td> <td>12-15-1982</td> <td>Chicago      </td> <td>Consumer Purchases                               </td> <td>General merchandise retailers have been unhappy with Chr ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2714 </td> <td>12-15-1982</td> <td>Chicago      </td> <td>.                                                </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2715 </td> <td>12-15-1982</td> <td>Chicago      </td> <td>Employment Losses                                </td> <td>Payroll employment in the five Seventh District states i ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>3171 </td> <td>9-20-1983 </td> <td>Philadelphia </td> <td>Financial                                        </td> <td>Local bankers say lean activity at major banks in the Th ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>3172 </td> <td>9-20-1983 </td> <td>Philadelphia </td> <td>pre-MMDA levels.                                 </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>3173 </td> <td>9-20-1983 </td> <td>Richmond     </td> <td>Overview                                         </td> <td>The economic expansion continues apace in the Fifth Dist ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5794 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>Inflation and Trade Expectations                 </td> <td>We asked manufacturers and retailers in the District to  ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5795 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>Respondents Expecting Rate of Increase to        </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5796 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>:                                                </td> <td>nan

# %%
ids_to_drop = [21]
h_h = [(30, 31)]
h_sh = [(92, 93), (121, 122), (135, 136), (216, 217), (258, 259), (584, 585), (628, 629)]
h_sh.extend([])

# %%
def merge_rows(id_1, id_2, table):
    new_row = []
    row_1 = table.where("ID", id_1).row(0)
    row_2 = table.where("ID", id_2).row(0)
    new_row.append(row_1[0], row_1[1], row_1[2], row_1[3])
    new_row.append(row_1[0] + row_2[4])

# %% [markdown]
# # Cleaning Strange Sector Headings

# %%
strange_headings = beige_books.where("Sector Heading", lambda s: len(s) < 5 and s != "Coal" and s != "Fuel")
strange_headings.show(3)
strange_heading_ids = strange_headings.apply(lambda i: int(i), "ID")
strange_heading_ids
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Date</th> <th>District</th> <th>Sector Heading</th> <th>Sector Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1989</td> <td>8-11-1981 </td> <td>Cleveland</td> <td><>            </td> <td>nan        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2456</td> <td>6-23-1982 </td> <td>Cleveland</td> <td><>            </td> <td>nan        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2714</td> <td>12-15-1982</td> <td>Chicago  </td> <td>.             </td> <td>nan        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (77 rows omitted)</p>
# array([ 1989,  2456,  2714,  5796,  5797,  5798,  5801,  5802,  5803,
#         5805,  5806,  5807,  5809,  5810,  5811,  5813,  5814,  5815,
#         6338,  6339,  6342,  6343,  6344,  6346,  6347,  6348,  6350,
#         6351,  6352,  6354,  6355,  6356,  6421,  6422,  6426,  6427,
#         6428,  6429,  6431,  6432,  6433,  6434,  6436,  6437,  6438,
#         6439,  6441,  6442,  6443,  6444,  6502,  6798,  6827,  6830,
#         6831,  6832,  6834,  6835,  6836,  6838,  6839,  6840,  8368,
#         8731, 10411, 14134, 14403, 18276, 19409, 20704, 21426, 21475,
#        21560, 21673, 22957, 24843, 25175, 25208, 25209, 25210])

# %%
strange_headings.show(300)
strange_heading_id = []
for i in strange_heading_ids:
    strange_heading_id.append(i)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Date</th> <th>District</th> <th>Sector Heading</th> <th>Sector Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1989 </td> <td>8-11-1981 </td> <td>Cleveland    </td> <td><>            </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2456 </td> <td>6-23-1982 </td> <td>Cleveland    </td> <td><>            </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2714 </td> <td>12-15-1982</td> <td>Chicago      </td> <td>.             </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5796 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>:             </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5797 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>Rise          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5798 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>Slow          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5801 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>40%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5802 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>10%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5803 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>50%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5805 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>23%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5806 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>16%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5807 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>61%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5809 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>56%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5810 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>19%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5811 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>25%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5813 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>9%            </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5814 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>52%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5815 </td> <td>6-15-1988 </td> <td>Richmond     </td> <td>39%           </td> <td>One of our manufacturing contacts said that inflation wo ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6338 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>Rise          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6339 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>Slow          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6342 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>15%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6343 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>26%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6344 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>60%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6346 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>21%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6347 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>16%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6348 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>62%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6350 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>24%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6351 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>42%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6352 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>34%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6354 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>32%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6355 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>25%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6356 </td> <td>6-21-1989 </td> <td>Richmond     </td> <td>43%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6421 </td> <td>8-9-1989  </td> <td>Richmond     </td> <td>Rise          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6422 </td> <td>8-9-1989  </td> <td>Richmond     </td> <td>Slow          </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6426 </td> <td>8-9-1989  </td> <td>Richmond     </td> <td>9%            </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6427 </td> <td>8-9-1989  </td> <td>Richmond     </td> <td>31%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6428 </td> <td>8-9-1989  </td> <td>Richmond     </td> <td>53%           </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6429 </td> <td>8-9-1989  </td> <td>Richmond     </td> <td>7%            </td> <td>nan                                                         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6431 </td> <td>8-

# %%
id_removal = strange_heading_ids[:50]
id_removal
# Out:
# array([1989, 2456, 2714, 5796, 5797, 5798, 5801, 5802, 5803, 5805, 5806,
#        5807, 5809, 5810, 5811, 5813, 5814, 5815, 6338, 6339, 6342, 6343,
#        6344, 6346, 6347, 6348, 6350, 6351, 6352, 6354, 6355, 6356, 6421,
#        6422, 6426, 6427, 6428, 6429, 6431, 6432, 6433, 6434, 6436, 6437,
#        6438, 6439, 6441, 6442, 6443, 6444])

# %%
no_strange_headings_beige_books = False

# %% [markdown]
# # Cleaning Strange Dates

# %%
def isNotDate(s):
    s = s.split("-")
    if len(s) != 3:
        return True
    if not s[0].isdigit():
        return True
    if not s[1].isdigit():
        return False
    if not s[2].isdigit():
        return True
    return False

strange_dates = beige_books.where("Date", isNotDate)
strange_dates.show(300)

strange_date_id = []
for i in strange_dates:
    strange_date_id.append(i)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>ID</th> <th>Date</th> <th>District</th> <th>Sector Heading</th> <th>Sector Text</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>132  </td> <td>1-1-, </td> <td>Boston       </td> <td>Summary of Economic Activity               </td> <td>The January 12, 1971 Boston report is not available.        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>395  </td> <td>11-1-,</td> <td>Boston       </td> <td>Summary of Economic Activity               </td> <td>Reports from our directors indicate business is continui ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>397  </td> <td>11-1-,</td> <td>Cleveland    </td> <td>Summary of Economic Activity               </td> <td>The thrust of recent statistical evidence and informatio ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>398  </td> <td>11-1-,</td> <td>Dallas       </td> <td>Summary of Economic Activity               </td> <td>Most major indicators of economic activity in the Eleven ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15959</td> <td>1-1-, </td> <td>Cleveland    </td> <td>Summary of Economic Activity               </td> <td>For the final six weeks of 2004, economic conditions wer ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15960</td> <td>1-1-, </td> <td>Cleveland    </td> <td>Manufacturing                              </td> <td>Production at the District's durable goods manufacturers ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15961</td> <td>1-1-, </td> <td>Cleveland    </td> <td>Retail Sales                               </td> <td>The economic environment for retailers in the District w ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15962</td> <td>1-1-, </td> <td>Cleveland    </td> <td>Construction                               </td> <td>Residential builders reported continuing declines in act ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15963</td> <td>1-1-, </td> <td>Cleveland    </td> <td>Banking                                    </td> <td>District banks described loan demand as steady, in gener ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15964</td> <td>1-1-, </td> <td>Cleveland    </td> <td>Trucking and Shipping                      </td> <td>Demand for trucking and shipping services remained stron ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19240</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Summary of Economic Activity               </td> <td>On balance, information from Sixth District business con ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19241</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Consumer Spending and Tourism              </td> <td>District retail contacts indicated that traffic and sale ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19242</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Real Estate and Construction               </td> <td>District homebuilders and Realtors both reported that th ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19243</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Manufacturing and Transportation           </td> <td>A small majority of manufacturing contacts noted moderat ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19244</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Banking and Finance                        </td> <td>District banking reports cited that lending conditions r ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19245</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Employment and Prices                      </td> <td>District businesses noted that the pace of layoffs slowe ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19246</td> <td>10-2-,</td> <td>Atlanta      </td> <td>Natural Resources and Agriculture          </td> <td>District contacts indicated that with petroleum and refi ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19247</td> <td>10-2-,</td> <td>Boston       </td> <td>Summary of Economic Activity               </td> <td>Business activity remains slow in the First District, no ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19248</td> <td>10-2-,</td> <td>Boston       </td> <td>Retail and Tourism                         </td> <td>Contacted retailers in the First District report mixed s ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19249</td> <td>10-2-,</td> <td>Boston       </td> <td>Manufacturing and Related Services         </td> <td>Manufacturing and related services contacts headquartere ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19250</td> <td>10-2-,</td> <td>Boston       </td> <td>Selected Business Services                 </td> <td>First District advertising and consulting contacts repor ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19251</td> <td>10-2-,</td> <td>Boston       </td> <td>Commercial Real Estate                     </td> <td>Commercial real estate contacts remain decidedly downbea ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19252</td> <td>10-2-,</td> <td>Boston       </td> <td>Residential Real Estate                    </td> <td>Following increases in June and July, residential real e ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19253</td> <td>10-2-,</td> <td>Chicago      </td> <td>Summary of Economic Activity               </td> <td>Economic activity in the Seventh District improved margi ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19254</td> <td>10-2-,</td> <td>Chicago      </td> <td>Consumer Spending                          </td> <td>Consumer spending decreased from the previous reporting  ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19255</td> <td>10-2-,</td> <td>Chicago      </td> <td>Business Spending                          </td> <td>The decline in business spending slowed in September and ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19256</td> <td>10-2-,</td> <td>Chicago      </td> <td>Construction and Real Estate               </td> <td>Construction activity in the District increased slightly ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19257</td> <td>10-2-,</td> <td>Chicago      </td> <td>Manufacturing                              </td> <td>Manufacturing activity in the District was slightly impr ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19258</td> <td>10-2-,</td> <td>Chicago      </td> <td>Banking and Finance                        </td> <td>Credit conditions, while still tight, further improved i ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19259</td> <td>10-2-,</td> <td>Chicago      </td> <td>Prices and Costs                           </td> <td>Price pressures were mixed in September and early Octobe ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19260</td> <td>10-2-,</td> <td>Chicago      </td> <td>Agriculture                                </td> <td>Harvesting the District's large corn and soybean crop wi ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19261</td> <td>10-2-,</td> <td>Cleveland    </td> <td>Summary of Economic Activity               </td> <td>The economy in the Fourth District has shown a few signs ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19262</td> <td>10-2-,</td> <td>Cleveland    </td> <td>Manufacturing                              </td> <td>Most reports from District factories showed that product ...</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19263</td> <td>10-2-,</td> <td>Cleveland    </td> <td>Real Estate                                </td> <td>A majority of home builders we contacted said that sales ...</td>
#         </tr>
#     </tbody>
#         <tr>

# %% [markdown]
# # Final Table

# %%
bad_flags = empty_row_id + strange_date_id + strange_heading_id
final = beige_books.where("ID", lambda s: int(s) not in bad_flags)

# %%
print("Post-cleaning length: " + str(final.num_rows))
# Out:
# Post-cleaning length: 25122

# %%
len(list(set(bad_flags)))
# Out:
# 152

# %%
final.to_csv("cleaned.csv")
